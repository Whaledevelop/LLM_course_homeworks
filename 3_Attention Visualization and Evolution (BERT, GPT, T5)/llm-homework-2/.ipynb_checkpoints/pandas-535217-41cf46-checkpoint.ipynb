# %% [markdown]
# # Pandas
#
# Краткий интерактивный ноутбук для быстрого освоения библиотеки **pandas** - на русском языке. Каждый раздел содержит пример кода и краткое пояснение[1].

# %% [markdown]
# ## Импорт необходимых библиотек
#
# **Совет преподавателя**: В мире анализа данных эти две библиотеки - ваши верные спутники:
# - **NumPy** - математический фундамент для работы с массивами и матрицами
# - **Pandas** - "швейцарский нож" для обработки табличных данных (как Excel, но мощнее!)
#
# **Конвенция**: Всегда импортируйте pandas как `pd`, а numpy как `np` - это стандарт, который используют все DS специалисты

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Основные структуры данных pandas
#
# **Аналогия для новичков**: Если представить данные как здание, то:
# - **Series** - это отдельная колонна здания. Одномерная структура с индексами, как список с подписанными элементами
# - **DataFrame** - это вся каркасная конструкция здания. Двумерная таблица, где Series объединены в единую структуру
#
# **Практическое понимание**:
# - Series = одна колонка в Excel с именами строк
# - DataFrame = целый лист Excel с именованными колонками и строками
#
# **Почему это важно**: 80% работы Data Scientist - это манипуляции с DataFrame'ами

# %% [markdown]
# ## Создание объектов
#
# **Урок первый**: Есть несколько способов создать данные в pandas. Начнем с самого простого.
#
# **Series из списка:**
#
# **Объяснение**: Series - это как улучшенный список Python. Обратите внимание, что pandas автоматически добавляет индексы (0, 1, 2...) и может работать с NaN (не число).

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
display(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# **DataFrame из numpy-матрицы с датами:**
#
# **Практический совет**: Это классический способ создания тестовых данных для экспериментов.
# - `pd.date_range()` создает последовательность дат
# - `np.random.randn()` генерирует случайные числа по нормальному распределению
# - Параметр `columns=list("ABCD")` создает колонки A, B, C, D

# %%
dates = pd.date_range("20130101", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=["A", "B", "C", "D"])
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %%
print(df)

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %%
display(df)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %% [markdown]
# **DataFrame из словаря:**
#
# **Важно понимать**: Этот пример показывает гибкость pandas — можете смешивать разные типы данных:
# - Числа с плавающей точкой (float)
# - Временные метки (Timestamp)
# - Категориальные данные (Categorical)
# - Массивы numpy
# - Просто строки
#
# **Обратите внимание на `df2.dtypes`** — это покажет, какие типы данных pandas автоматически определил для каждой колонки.

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20130102"),
    "C": pd.Series(1, index=list(range(4)), dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo"
})
display(df2)
display(df2.dtypes)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
d = {"client_id": [112321, 41323123, 432543], "message_history": ["\n".join(["a", "b", "c"]), "\n".join(["a", "b", "c"]), "\n".join(["a", "b", "c"])]}
d
# Out:
# {'client_id': [112321, 41323123, 432543],
#  'message_history': ['a\nb\nc', 'a\nb\nc', 'a\nb\nc']}

# %%
print('a\nb\nc')
# Out:
# a
# b
# c

# %%
pd.DataFrame(d)
# Out:
#    client_id message_history
# 0     112321         a\nb\nc
# 1   41323123         a\nb\nc
# 2     432543         a\nb\nc

# %% [markdown]
# ## Просмотр данных
#
# **Урок второй**: Первое, что делает любой аналитик после загрузки данных — это "разведка". Вот основные команды разведчика:
#
# **Первые строки:**
#
# **Зачем это нужно**: `head()` показывает первые 5 строк (по умолчанию). Это как "предварительный просмотр" ваших данных. Помогает понять структуру и типы данных.

# %%
display(df.head())
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964

# %% [markdown]
# **Последние строки:**
#
# **Практический совет**: `tail(3)` показывает последние 3 строки. Особенно полезно для проверки, что данные загрузились полностью и нет обрезки в конце файла.

# %%
display(df.tail(3))
# Out:
#                    A         B         C         D
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %% [markdown]
# **Индексы и столбцы:**
#
# **Понимание архитектуры**:
# - `df.index` — показывает метки строк (в нашем случае — даты)
# - `df.columns` — показывает названия столбцов
# - Это основа для навигации по данным

# %%
print(df.index)
print(df.columns)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# **Массив numpy данных:**
#
# **Под капотом**: `to_numpy()` показывает сырые данные без индексов и названий колонок. Иногда нужно для передачи в алгоритмы машинного обучения, которые работают с numpy массивами.

# %%
print(df.to_numpy())
print(df2.to_numpy())
# Out:
# [[-0.24419534  0.30702465  0.25345338 -0.65717179]
#  [ 0.76958882 -1.01412545  0.10970909 -0.77040473]
#  [-0.73002258 -0.23649274  0.0547216   0.47819591]
#  [-1.05732913 -0.28607296  0.25929189 -1.04929738]
#  [ 0.08965969  0.86746881  0.80637672  1.70596402]
#  [ 0.22305121  0.97040836  0.37067439 -0.98637355]]
# [[1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'train' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'train' 'foo']]

# %% [markdown]
# ## Быстрые статистики
#
# **Урок третий**: Разведочный анализ данных начинается с базовой статистики.
#
# **Краткое описание:**
#
# **Золотая команда**: `describe()` — ваш лучший друг! Показывает count (количество), mean (среднее), std (стандартное отклонение), min/max и квартили. Это первое, что нужно запустить на новых данных.

# %% [markdown]
# **Транспонирование:**

# %%
display(df.T)
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.244195    0.769589   -0.730023   -1.057329    0.089660    0.223051
# B    0.307025   -1.014125   -0.236493   -0.286073    0.867469    0.970408
# C    0.253453    0.109709    0.054722    0.259292    0.806377    0.370674
# D   -0.657172   -0.770405    0.478196   -1.049297    1.705964   -0.986374

# %% [markdown]
# **Сортировка по оси или значениям:**

# %%
display(df.sort_index(axis=1, ascending=False))
display(df.sort_values(by="B"))
# Out:
#                    D         C         B         A
# 2013-01-01 -0.657172  0.253453  0.307025 -0.244195
# 2013-01-02 -0.770405  0.109709 -1.014125  0.769589
# 2013-01-03  0.478196  0.054722 -0.236493 -0.730023
# 2013-01-04 -1.049297  0.259292 -0.286073 -1.057329
# 2013-01-05  1.705964  0.806377  0.867469  0.089660
# 2013-01-06 -0.986374  0.370674  0.970408  0.223051
#                    A         B         C         D
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %% [markdown]
# ## Выбор данных
#
# **Урок четвертый**: Самый важный навык — уметь "нарезать" данные нужными кусочками.
#
# **По ключу (столбец):**
#
# **Основы индексации**: `df["A"]` — выбираете колонку A. Получаете Series. Это как выбрать одну колонку в Excel.

# %%
display(df["A"])
# Out:
# 2013-01-01   -0.244195
# 2013-01-02    0.769589
# 2013-01-03   -0.730023
# 2013-01-04   -1.057329
# 2013-01-05    0.089660
# 2013-01-06    0.223051
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# **По срезу строк:**
#
# **Понимание срезов**:
# - `df[0:3]` — строки по позициям (первые 3)
# - `df["20130102":"20130104"]` — строки по значениям индекса (по датам)
# - Pandas умный: понимает, что вы хотите выбрать по датам!

# %%
display(df[0:3])
display(df["20130102":"20130104"])
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
#                    A         B         C         D
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297

# %% [markdown]
# **По метке с помощью loc:**
#
# **Мастер-класс loc**:
# - `loc` = location (местоположение)
# - `df.loc[строки, колонки]` — явное указание что и где выбирать
# - `:` означает "все" (как в numpy)
# - `loc` работает с МЕТКАМИ (названиями), а не позициями

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %%
display(df.loc[dates[0]])
display(df.loc[:, ["A", "B"]])
display(df.loc["20130102":"20130104", ["A", "B"]])
display(df.loc[dates[0], "A"])
# Out:
# A   -0.244195
# B    0.307025
# C    0.253453
# D   -0.657172
# Name: 2013-01-01 00:00:00, dtype: float64
#                    A         B
# 2013-01-01 -0.244195  0.307025
# 2013-01-02  0.769589 -1.014125
# 2013-01-03 -0.730023 -0.236493
# 2013-01-04 -1.057329 -0.286073
# 2013-01-05  0.089660  0.867469
# 2013-01-06  0.223051  0.970408
#                    A         B
# 2013-01-02  0.769589 -1.014125
# 2013-01-03 -0.730023 -0.236493
# 2013-01-04 -1.057329 -0.286073
# np.float64(-0.2441953365092659)

# %% [markdown]
# **По позиции с помощью iloc:**
#
# **Мастер-класс iloc**:
# - `iloc` = integer location (целочисленное местоположение)
# - `df.iloc[строки, колонки]` — работает только с ЧИСЛОВЫМИ позициями
# - Как индексы в обычных списках Python: 0, 1, 2...
# - `iloc[1, 1]` — строка 1, колонка 1 (начиная с 0)

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374

# %%
display(df.iloc[3])
display(df.iloc[3:5, 0:2])
display(df.iloc[[1, 2, 4], [0, 2]])
display(df.iloc[1:3, :])
display(df.iloc[:, 1:3])
display(df.iloc[1, 1])
# Out:
# A   -1.514305
# B   -0.619405
# C    0.705158
# D   -0.531867
# Name: 2013-01-04 00:00:00, dtype: float64
#                    A         B
# 2013-01-04 -1.514305 -0.619405
# 2013-01-05 -2.192318  0.466330
#                    A         C
# 2013-01-02  1.140674 -0.118477
# 2013-01-03 -0.225216  0.279338
# 2013-01-05 -2.192318 -1.175133
#                    A         B         C         D
# 2013-01-02  1.140674  1.554574 -0.118477 -0.911598
# 2013-01-03 -0.225216 -0.364302  0.279338  2.037006
#                    B         C
# 2013-01-01  0.702365 -0.082195
# 2013-01-02  1.554574 -0.118477
# 2013-01-03 -0.364302  0.279338
# 2013-01-04 -0.619405  0.705158
# 2013-01-05  0.466330 -1.175133
# 2013-01-06  0.979375  0.116342
# np.float64(1.554573845479664)

# %% [markdown]
# ## Булевый индекс
#
# **Урок пятый**: Самая мощная фича pandas — фильтрация по условиям!
#
# **Фильтрация по условию:**
#
# **Магия булевых масок**:
# - `df["A"] > 0` создает маску True/False для каждой строки
# - `df[маска]` оставляет только строки где True
# - Это основа для всех фильтров в анализе данных!

# %%
display(df[df["A"] > 0])
display(df[df > 0])
# Out:
#                    A         B         C         D
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374
#                    A         B         C         D
# 2013-01-01       NaN  0.307025  0.253453       NaN
# 2013-01-02  0.769589       NaN  0.109709       NaN
# 2013-01-03       NaN       NaN  0.054722  0.478196
# 2013-01-04       NaN       NaN  0.259292       NaN
# 2013-01-05  0.089660  0.867469  0.806377  1.705964
# 2013-01-06  0.223051  0.970408  0.370674       NaN

# %% [markdown]
# **Фильтрация по значениям:**
#
# **Продвинутая фильтрация**:
# - `isin([список])` — проверяет, входит ли значение в список
# - Аналог SQL: `WHERE column IN ('val1', 'val2')`
# - Очень удобно для категориальных данных

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.244195  0.307025  0.253453 -0.657172    one
# 2013-01-02  0.769589 -1.014125  0.109709 -0.770405    one
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196    two
# 2013-01-04 -1.057329 -0.286073  0.259292 -1.049297  three
# 2013-01-05  0.089660  0.867469  0.806377  1.705964   four
# 2013-01-06  0.223051  0.970408  0.370674 -0.986374  three

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
display(df2[df2["E"].isin(["two", "four"])])
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.730023 -0.236493  0.054722  0.478196   two
# 2013-01-05  0.089660  0.867469  0.806377  1.705964  four

# %% [markdown]
# ## Изменение данных
#
# **Добавление столбца:**

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
df["F"] = s1

# %% [markdown]
# **Изменение значений по метке или позиции:**

# %%
df.at[dates[0], "A"] = 0
df.iat[0, 1] = 0
df.loc[:, "D"] = np.array([5] * len(df))
display(df)
# Out:
#                    A         B         C    D    F  ZZXCXZC
# 2013-01-01  0.000000  0.000000  0.253453  5.0  NaN        1
# 2013-01-02  0.769589 -1.014125  0.109709  5.0  1.0        1
# 2013-01-03 -0.730023 -0.236493  0.054722  5.0  2.0        1
# 2013-01-04 -1.057329 -0.286073  0.259292  5.0  3.0        1
# 2013-01-05  0.089660  0.867469  0.806377  5.0  4.0        1
# 2013-01-06  0.223051  0.970408  0.370674  5.0  5.0        1

# %% [markdown]
# **where-операция:**

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C    D    F  ZZXCXZC
# 2013-01-01  0.000000  0.000000  0.253453  5.0  NaN        1
# 2013-01-02  0.769589 -1.014125  0.109709  5.0  1.0        1
# 2013-01-03 -0.730023 -0.236493  0.054722  5.0  2.0        1
# 2013-01-04 -1.057329 -0.286073  0.259292  5.0  3.0        1
# 2013-01-05  0.089660  0.867469  0.806377  5.0  4.0        1
# 2013-01-06  0.223051  0.970408  0.370674  5.0  5.0        1

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
display(df2)
# Out:
#                    A         B         C    D    F  ZZXCXZC
# 2013-01-01  0.000000  0.000000 -0.253453 -5.0  NaN       -1
# 2013-01-02 -0.769589 -1.014125 -0.109709 -5.0 -1.0       -1
# 2013-01-03 -0.730023 -0.236493 -0.054722 -5.0 -2.0       -1
# 2013-01-04 -1.057329 -0.286073 -0.259292 -5.0 -3.0       -1
# 2013-01-05 -0.089660 -0.867469 -0.806377 -5.0 -4.0       -1
# 2013-01-06 -0.223051 -0.970408 -0.370674 -5.0 -5.0       -1

# %% [markdown]
# ## Работа с пропущенными данными
#
# **Проверка, заполнение и удаление:**

# %%
df1
# Out:
#                    A         B         C    D    F  ZZXCXZC    E
# 2013-01-01  0.000000  0.000000  0.253453  5.0  NaN        1  1.0
# 2013-01-02  0.769589 -1.014125  0.109709  5.0  1.0        1  1.0
# 2013-01-03 -0.730023 -0.236493  0.054722  5.0  2.0        1  NaN
# 2013-01-04 -1.057329 -0.286073  0.259292  5.0  3.0        1  NaN

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0]:dates[1], "E"] = 1
display(df1.dropna(how="any"))
# Out:
#                    A         B         C    D    F  ZZXCXZC    E
# 2013-01-02  0.769589 -1.014125  0.109709  5.0  1.0        1  1.0

# %%
display(df1.fillna(value=5))
# Out:
#                    A         B         C    D    F  ZZXCXZC    E
# 2013-01-01  0.000000  0.000000  0.253453  5.0  5.0        1  1.0
# 2013-01-02  0.769589 -1.014125  0.109709  5.0  1.0        1  1.0
# 2013-01-03 -0.730023 -0.236493  0.054722  5.0  2.0        1  5.0
# 2013-01-04 -1.057329 -0.286073  0.259292  5.0  3.0        1  5.0

# %%
display(pd.isna(df1))
# Out:
#                 A      B      C      D      F  ZZXCXZC      E
# 2013-01-01  False  False  False  False   True    False  False
# 2013-01-02  False  False  False  False  False    False  False
# 2013-01-03  False  False  False  False  False    False   True
# 2013-01-04  False  False  False  False  False    False   True

# %% [markdown]
# ## Операции
#
# **Урок шестой**: Pandas — это Excel на стероидах. Любые вычисления по строкам и колонкам.
#
# **Статистика по столбцам и строкам:**
#
# **Понимание осей**:
# - `axis=0` или без параметра — операция по колонкам (результат для каждой колонки)
# - `axis=1` — операция по строкам (результат для каждой строки)
# - Запомните: axis=0 "схлопывает" строки, axis=1 "схлопывает" колонки

# %%
display(df.mean())
display(df.mean(axis=1))
# Out:
# A         -0.117509
# B          0.050198
# C          0.309038
# D          5.000000
# F          3.000000
# ZZXCXZC    1.000000
# dtype: float64
# 2013-01-01    1.250691
# 2013-01-02    1.144195
# 2013-01-03    1.181368
# 2013-01-04    1.319315
# 2013-01-05    1.960584
# 2013-01-06    2.094022
# Freq: D, dtype: float64

# %% [markdown]
# **Операции с выравниванием по индексам:**

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
display(df.sub(s, axis="index"))
# Out:
#                    A         B         C    D    F  ZZXCXZC
# 2013-01-01       NaN       NaN       NaN  NaN  NaN      NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN      NaN
# 2013-01-03 -1.730023 -1.236493 -0.945278  4.0  1.0      0.0
# 2013-01-04 -4.057329 -3.286073 -2.740708  2.0  0.0     -2.0
# 2013-01-05 -4.910340 -4.132531 -4.193623  0.0 -1.0     -4.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN      NaN

# %% [markdown]
# **Собственные функции и трансформации:**

# %%
df3 = pd.DataFrame({"A": [1, 2, 3], "B": ["Q", "W", "Q"]})
df3
# Out:
#    A  B
# 0  1  Q
# 1  2  W
# 2  3  Q

# %%
df3.groupby(by="B").mean()
# Out:
#      A
# B
# Q  2.0
# W  2.0

# %%
display(df.agg(lambda x: np.mean(x) * 5.6))
display(df.transform(lambda x: x * 101.2))
# Out:
# A          -0.658049
# B           0.281107
# C           1.730612
# D          28.000000
# F          16.800000
# ZZXCXZC     5.600000
# dtype: float64
#                      A           B          C      D      F  ZZXCXZC
# 2013-01-01    0.000000    0.000000  25.649482  506.0    NaN    101.2
# 2013-01-02   77.882388 -102.629496  11.102560  506.0  101.2    101.2
# 2013-01-03  -73.878285  -23.933066   5.537826  506.0  202.4    101.2
# 2013-01-04 -107.001708  -28.950583  26.240339  506.0  303.6    101.2
# 2013-01-05    9.073561   87.787844  81.605325  506.0  404.8    101.2
# 2013-01-06   22.572783   98.205326  37.512248  506.0  506.0    101.2

# %% [markdown]
# **Value Counts и строковые методы:**

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
display(s.value_counts())

s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
display(s.str.lower())
# Out:
# 3    3
# 1    2
# 4    2
# 0    1
# 6    1
# 5    1
# Name: count, dtype: int64
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Объединение данных
#
# **Конкатенация:**

# %%
df[:3]
# Out:
#           0         1         2         3
# 0 -0.139216 -0.330745  0.418176  1.605538
# 1  1.051888  0.743155 -0.223960  1.143753
# 2 -1.911578 -1.750434 -0.725443  0.995780

# %%
df[3:7]
# Out:
#           0         1         2         3
# 3 -1.842960  0.046527 -0.874451 -0.625165
# 4  0.257114 -1.161815  0.021498 -0.020941
# 5  0.748132 -0.435096 -0.033777  0.443265
# 6  1.421893 -1.052772 -0.041698 -1.382280

# %%
df[7:]
# Out:
#           0         1         2         3
# 7 -1.482294 -0.775643 -1.088372  0.309862
# 8 -1.363110 -1.276408 -1.744272 -0.135086
# 9 -0.189263 -2.292319 -1.742941 -0.281639

# %%
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]
display(pd.concat(pieces))
# Out:
#           0         1         2         3
# 0 -0.139216 -0.330745  0.418176  1.605538
# 1  1.051888  0.743155 -0.223960  1.143753
# 2 -1.911578 -1.750434 -0.725443  0.995780
# 3 -1.842960  0.046527 -0.874451 -0.625165
# 4  0.257114 -1.161815  0.021498 -0.020941
# 5  0.748132 -0.435096 -0.033777  0.443265
# 6  1.421893 -1.052772 -0.041698 -1.382280
# 7 -1.482294 -0.775643 -1.088372  0.309862
# 8 -1.363110 -1.276408 -1.744272 -0.135086
# 9 -0.189263 -2.292319 -1.742941 -0.281639

# %% [markdown]
# **SQL-подобное объединение (merge):**

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
display(pd.merge(left, right, on="key"))
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ## Группировка
#
# **Урок седьмой**: Группировка — это SQL в pandas. Самая мощная техника для анализа.
#
# **Группировка и агрегация:**
#
# **Концепция группировки**:
# 1. **Split** (разделить) — разбиваем данные по группам
# 2. **Apply** (применить) — применяем функцию к каждой группе
# 3. **Combine** (объединить) — собираем результаты обратно
#
# **Практическое применение**:
# - `groupby("A")` — группируем по колонке A
# - `[["C", "D"]]` — выбираем колонки для агрегации
# - `.sum()` — применяем функцию суммирования к каждой группе

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.801300  0.711927
# 1  bar    one  1.009342 -0.777100
# 2  foo    two -0.773367 -1.894443
# 3  bar  three  0.751641  0.401796
# 4  foo    two -1.594193  0.858115
# 5  bar    two  0.608745 -1.777837
# 6  foo    one  1.213167  0.488301
# 7  foo  three -0.751921  0.652434

# %%
df = pd.DataFrame({
    "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
    "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
    "C": np.random.randn(8),
    "D": np.random.randn(8)
})
display(df.groupby("A")[["C", "D"]].sum())
display(df.groupby(["A", "B"]).sum())
# Out:
#             C         D
# A
# bar  2.369728 -2.153140
# foo -1.105013  0.816333
#                   C         D
# A   B
# bar one    1.009342 -0.777100
#     three  0.751641  0.401796
#     two    0.608745 -1.777837
# foo one    2.014467  1.200228
#     three -0.751921  0.652434
#     two   -2.367560 -1.036328

# %% [markdown]
# ## Изменение формы данных
#
# **Stack/Unstack и сводные таблицы:**

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
    ["one", "two", "one", "two", "one", "two", "one", "two"],
]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
stacked = df2.stack()
display(stacked)
display(stacked.unstack())
display(stacked.unstack(1))
display(stacked.unstack(0))
# Out:
# first  second
# bar    one     A    0.676707
#                B    0.191880
#        two     A    1.397886
#                B   -0.393147
# baz    one     A   -0.264225
#                B   -0.189797
#        two     A    0.304313
#                B    0.758327
# dtype: float64
#                      A         B
# first second
# bar   one     0.676707  0.191880
#       two     1.397886 -0.393147
# baz   one    -0.264225 -0.189797
#       two     0.304313  0.758327
# second        one       two
# first
# bar   A  0.676707  1.397886
#       B  0.191880 -0.393147
# baz   A -0.264225  0.304313
#       B -0.189797  0.758327
# first          bar       baz
# second
# one    A  0.676707 -0.264225
#        B  0.191880 -0.189797
# two    A  1.397886  0.304313
#        B -0.393147  0.758327

# %%
# Сводная таблица
df = pd.DataFrame({
    "A": ["one", "one", "two", "three"] * 3,
    "B": ["A", "B", "C"] * 4,
    "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
    "D": np.random.randn(12),
    "E": np.random.randn(12),
})
display(pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"]))
# Out:
# C             bar       foo
# A     B
# one   A -0.420041 -1.682164
#       B -2.193747  0.608792
#       C  0.754827 -1.334768
# three A -0.390453       NaN
#       B       NaN -1.446170
#       C -1.160782       NaN
# two   A       NaN -0.387483
#       B  0.410265       NaN
#       C       NaN  0.749455

# %% [markdown]
# ## Временные ряды
#
# **Создание меток, ресемплирование, работа с временными зонами:**

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
display(ts.resample("5Min").sum())
# Out:
# 2012-01-01    25117
# Freq: 5min, dtype: int64

# %%
# Временная зона
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts_utc = ts.tz_localize("UTC")
display(ts_utc)
display(ts_utc.tz_convert("US/Eastern"))
# Out:
# 2012-03-06 00:00:00+00:00   -0.801795
# 2012-03-07 00:00:00+00:00    0.410263
# 2012-03-08 00:00:00+00:00    0.025375
# 2012-03-09 00:00:00+00:00   -0.653735
# 2012-03-10 00:00:00+00:00   -0.377293
# Freq: D, dtype: float64
# 2012-03-05 19:00:00-05:00   -0.801795
# 2012-03-06 19:00:00-05:00    0.410263
# 2012-03-07 19:00:00-05:00    0.025375
# 2012-03-08 19:00:00-05:00   -0.653735
# 2012-03-09 19:00:00-05:00   -0.377293
# Freq: D, dtype: float64

# %% [markdown]
# ## Категориальные данные
#
# **Работа с категориями:**

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]})
df["grade"] = df["raw_grade"].astype("category")
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
display(df["grade"])
display(df.sort_values(by="grade"))
display(df.groupby("grade", observed=False).size())
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Импорт и экспорт данных
#
# **CSV:**

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")  # если сохранить без параметра index=False
pd.read_csv("foo.csv")  # то при чтении получим дополнительный столбец "Unnamed: 0", в котором будут индексы сохранённого датафрейма
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  3  4  4  1
# 1           1  2  3  0  0  0
# 2           2  3  2  1  2  3
# 3           3  0  2  1  1  2
# 4           4  1  2  3  2  0
# 5           5  3  3  0  3  3
# 6           6  0  4  4  4  0
# 7           7  1  1  2  1  0
# 8           8  4  2  0  2  1
# 9           9  1  4  0  3  4

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv", index=False)
pd.read_csv("foo.csv")
# Out:
#    0  1  2  3  4
# 0  3  2  4  0  0
# 1  1  3  3  3  0
# 2  2  1  3  0  2
# 3  3  1  0  1  4
# 4  1  4  4  4  3
# 5  2  1  4  4  0
# 6  4  1  4  0  1
# 7  2  4  2  4  1
# 8  2  0  4  4  0
# 9  3  3  1  4  2

# %% [markdown]
# **Parquet:**

# %%
df.to_parquet("foo.parquet", index=False)
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  3  2  4  0  0
# 1  1  3  3  3  0
# 2  2  1  3  0  2
# 3  3  1  0  1  4
# 4  1  4  4  4  3
# 5  2  1  4  4  0
# 6  4  1  4  0  1
# 7  2  4  2  4  1
# 8  2  0  4  4  0
# 9  3  3  1  4  2

# %% [markdown]
# **Excel:**

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1", index=False)
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    0  1  2  3  4
# 0  3  2  4  0  0
# 1  1  3  3  3  0
# 2  2  1  3  0  2
# 3  3  1  0  1  4
# 4  1  4  4  4  3
# 5  2  1  4  4  0
# 6  4  1  4  0  1
# 7  2  4  2  4  1
# 8  2  0  4  4  0
# 9  3  3  1  4  2

# %% [markdown]
# ## Подводные камни
#
# **Важное предупреждение**: Самая частая ошибка новичков!
#
# **Проблема неоднозначности**: Series нельзя использовать в условии if напрямую, потому что в нем много значений. Python не знает, какое именно проверять.
#
# **Решения**:
# - `.any()` — True если хотя бы одно значение True
# - `.all()` — True если все значения True
# - `.empty` — True если Series пустой
# - `.bool()` — для Series из одного элемента

# %%
if pd.Series([False, True, False]):
    print("I was true")
# ValueError: The truth value of a Series is ambiguous.
# Используйте: .empty, .bool(), .item(), .any() или .all()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-112-1591557055.py in <cell line: 0>()
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#       3 # ValueError: The truth value of a Series is ambiguous.
#       4 # Используйте: .empty, .bool(), .item(), .any() или .all()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
if all([False, True, False]):
    print("I was true")

# %%
if pd.Series([False, True, False]).any():
    print("I was true")
# Out:
# I was true

# %%
if pd.Series([False, True, False]).all():
    print("I was true")
else:
    print("I was false")
# Out:
# I was false

# %% [markdown]
# ---
#
# > **Полная документация и дополнительные примеры доступны на официальном сайте библиотеки pandas[1].**
#
# [1] https://pandas.pydata.org/docs/user_guide/10min.html
